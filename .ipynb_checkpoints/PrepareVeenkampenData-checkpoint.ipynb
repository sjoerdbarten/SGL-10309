# %%
#IMPORT FUNCTIONS ANS DEFINE START_DATE AND END_DATE
#ONLY CHANGE THIS CELL IF ADJUSTED FOR YEARS
import numpy as np
import pandas as pd
import os
from os import listdir
from os.path import isfile, join
import requests
import datetime as dt
from fetch_data import *
from dateutil.relativedelta import relativedelta
pd.set_option('display.max_rows', 50)

# Define start and end dates
start_date = dt.datetime(2013, 1, 1)
end_date = dt.datetime(2014, 1, 1)

#Define API KEY MAQ-Observations
site = 1                                          #1=Veenkampen
variables = ['SW_IN_1_1_1','TA_1_1_2','RH_1_1_1','WS_2_1_1','P_1_1_7','VWC_1_1_1','VWC_1_2_1','VWC_1_3_1','VWC_1_4_1']                                 
API_KEY = '2ece4599-3157-40bf-ae13-351e1eb3ae92'  #Put you API key here as a string, see https://maq-observations.nl/api/
save_filename = 'MAQ-Observations_request.csv'    #You can define the name of the file you want to save your data to

#OUTPUT FILE WILL BE:
#Data_Meteo_Veenkampen_{start_date.year}-{end_date.year}.csv

'''
date-time;year;month;day-of-month;hour;Rg;Ta;RH;u;P;smc_065;smc_125;smc_250;smc_500
2013-01-01 0:00;2013;1;1;0;0.0;8.6;90.04;8.6;1.0;0.71;0.69;0.69;0.74
2013-01-01 1:00;2013;1;1;1;0.0;8.4;91.31;8.1;2.0;0.71;0.69;0.69;0.74
2013-01-01 2:00;2013;1;1;2;0.0;8.3;91.62;7.5;0.6;0.71;0.69;0.69;0.74
2013-01-01 3:00;2013;1;1;3;0.0;8.2;92.01;6.7;1.8;0.71;0.69;0.69;0.74
2013-01-01 4:00;2013;1;1;4;0.0;8.2;92.67;7.1;1.3;0.71;0.69;0.69;0.74
2013-01-01 5:00;2013;1;1;5;0.0;8.2;92.98;6.7;0.4;0.71;0.69;0.69;0.74
2013-01-01 6:00;2013;1;1;6;0.0;8.3;93.38;6.9;0.1;0.71;0.69;0.69;0.74
2013-01-01 7:00;2013;1;1;7;0.0;8.4;92.55;6.4;4.3;0.71;0.69;0.69;0.74
2013-01-01 8:00;2013;1;1;8;0.0;8.4;91.76;6.1;1.7;0.71;0.69;0.69;0.74
2013-01-01 9:00;2013;1;1;9;7.8;7.9;92.69;3.7;0.2;0.71;0.69;0.69;0.74
'''
# Out:
# '\ndate-time;year;month;day-of-month;hour;Rg;Ta;RH;u;P;smc_065;smc_125;smc_250;smc_500\n2013-01-01 0:00;2013;1;1;0;0.0;8.6;90.04;8.6;1.0;0.71;0.69;0.69;0.74\n2013-01-01 1:00;2013;1;1;1;0.0;8.4;91.31;8.1;2.0;0.71;0.69;0.69;0.74\n2013-01-01 2:00;2013;1;1;2;0.0;8.3;91.62;7.5;0.6;0.71;0.69;0.69;0.74\n2013-01-01 3:00;2013;1;1;3;0.0;8.2;92.01;6.7;1.8;0.71;0.69;0.69;0.74\n2013-01-01 4:00;2013;1;1;4;0.0;8.2;92.67;7.1;1.3;0.71;0.69;0.69;0.74\n2013-01-01 5:00;2013;1;1;5;0.0;8.2;92.98;6.7;0.4;0.71;0.69;0.69;0.74\n2013-01-01 6:00;2013;1;1;6;0.0;8.3;93.38;6.9;0.1;0.71;0.69;0.69;0.74\n2013-01-01 7:00;2013;1;1;7;0.0;8.4;92.55;6.4;4.3;0.71;0.69;0.69;0.74\n2013-01-01 8:00;2013;1;1;8;0.0;8.4;91.76;6.1;1.7;0.71;0.69;0.69;0.74\n2013-01-01 9:00;2013;1;1;9;7.8;7.9;92.69;3.7;0.2;0.71;0.69;0.69;0.74\n'

# %%
# Transform the data to the desired format
def transform_data(df):
    # Extract year, month, day, and hour from the 'begindatumtijd' column
    df['date-time'] = pd.to_datetime(df['date-time'])
    df['date-time'] = df['date-time'].dt.strftime('%Y-%m-%d %H:%M:%S')

    df["date-time"] = pd.to_datetime(df["date-time"])  # Ensure datetime format
    df.set_index("date-time", inplace=True)  # Set datetime as index

    agg_rules = {
        "Rg": lambda x: np.nanmean(x),
        "Ta": lambda x: np.nanmean(x),
        "RH": lambda x: np.nanmean(x),
        "u": lambda x: np.nanmean(x),
        "P": lambda x: np.nansum(x),
        "smc_065": lambda x: np.nanmean(x),
        "smc_125": lambda x: np.nanmean(x),
        "smc_250": lambda x: np.nanmean(x),
        "smc_500": lambda x: np.nanmean(x),
    }

    df_hourly = df.resample("H").agg(agg_rules)
    df_hourly = df_hourly.round(3)
    df_hourly.reset_index(inplace=True)

    df_hourly['year'] = df_hourly['date-time'].dt.year
    df_hourly['month'] = df_hourly['date-time'].dt.month
    df_hourly['day'] = df_hourly['date-time'].dt.day
    df_hourly['hour'] = df_hourly['date-time'].dt.hour

    # Reorder the columns to match the desired output
    df_hourly = df_hourly[["date-time", "year", "month", "day", "hour", "Rg", "Ta", "RH", "u", "P", "smc_065", "smc_125", "smc_250", "smc_500"]]
    
    return df_hourly

# Create a function to fill missing times with NaN
def fill_missing_times(df, start_date, end_date):
    # Create a complete time range from start_date to end_date with a frequency of 1 minute
    complete_time_range = pd.date_range(start=start_date, end=end_date, freq='H')
    
    # Create a DataFrame with the complete time range as 'date-time'
    complete_df = pd.DataFrame({'date-time': complete_time_range})
    
    # Ensure both 'date-time' columns are of datetime type
    complete_df['date-time'] = pd.to_datetime(complete_df['date-time'])
    df['date-time'] = pd.to_datetime(df['date-time'])
    
    # Merge the complete DataFrame with the existing data to ensure all times are included
    df = pd.merge(complete_df, df, on='date-time', how='left')
    
    # Reorder the columns and return the result
    df['year'] = df['date-time'].dt.year
    df['month'] = df['date-time'].dt.month
    df['day'] = df['date-time'].dt.day
    df['hour'] = df['date-time'].dt.hour
    df = df[["date-time", "year", "month", "day", "hour", "Rg", "Ta", "RH", "u", "P", "smc_065", "smc_125", "smc_250", "smc_500"]]
    
    return df

# %%
#ACTUAL CODE (NO NEED TO CHANGE)

df_all = pd.DataFrame()
df_veenkampen_list = []

# Loop over each year from start_date to end_date
current_date = start_date
while current_date <= end_date:
    year = current_date.year
    month = current_date.month
    end_date_month = current_date + relativedelta(months=1)
    print("Processing year "+str(year)+" month "+str(month))

    month_data = fetch_data(current_date,end_date_month,site,variables,API_KEY,False,save_filename).drop(index=0).reset_index(drop=True)
            
    df_veenkampen_list.append(month_data)

    current_date = current_date + relativedelta(months=1)
#ENDOFLOOP


# Concatenate all dataframes for each location into separate DataFrames
df_veenkampen_final = pd.concat(df_veenkampen_list, ignore_index=True)

# Rename columns
column_mapping = {
    "Timestamp": "date-time",
    "SW_IN_1_1_1": "Rg",
    "TA_1_1_2": "Ta",
    "RH_1_1_1": "RH",
01
# Processing variable RH_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48655/measures?from=2013-10-01&to=2013-11-01
# Processing variable WS_2_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48669/measures?from=2013-10-01&to=2013-11-01
# Processing variable P_1_1_7 at https://maq-observations.nl/wp-json/maq/v1/streams/48666/measures?from=2013-10-01&to=2013-11-01
# Processing variable VWC_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49275/measures?from=2013-10-01&to=2013-11-01
# Processing variable VWC_1_2_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49276/measures?from=2013-10-01&to=2013-11-01
# Processing variable VWC_1_3_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49277/measures?from=2013-10-01&to=2013-11-01
# Processing variable VWC_1_4_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49278/measures?from=2013-10-01&to=2013-11-01
# Processing year 2013 month 11
# Processing variable SW_IN_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48656/measures?from=2013-11-01&to=2013-12-01
# Processing variable TA_1_1_2 at https://maq-observations.nl/wp-json/maq/v1/streams/48654/measures?from=2013-11-01&to=2013-12-01
# Processing variable RH_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48655/measures?from=2013-11-01&to=2013-12-01
# Processing variable WS_2_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48669/measures?from=2013-11-01&to=2013-12-01
# Processing variable P_1_1_7 at https://maq-observations.nl/wp-json/maq/v1/streams/48666/measures?from=2013-11-01&to=2013-12-01
# Processing variable VWC_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49275/measures?from=2013-11-01&to=2013-12-01
# Processing variable VWC_1_2_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49276/measures?from=2013-11-01&to=2013-12-01
# Processing variable VWC_1_3_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49277/measures?from=2013-11-01&to=2013-12-01
# Processing variable VWC_1_4_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49278/measures?from=2013-11-01&to=2013-12-01
# Processing year 2013 month 12
# Processing variable SW_IN_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48656/measures?from=2013-12-01&to=2014-01-01
# Processing variable TA_1_1_2 at https://maq-observations.nl/wp-json/maq/v1/streams/48654/measures?from=2013-12-01&to=2014-01-01
# Processing variable RH_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48655/measures?from=2013-12-01&to=2014-01-01
# Processing variable WS_2_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48669/measures?from=2013-12-01&to=2014-01-01
# Processing variable P_1_1_7 at https://maq-observations.nl/wp-json/maq/v1/streams/48666/measures?from=2013-12-01&to=2014-01-01
# Processing variable VWC_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49275/measures?from=2013-12-01&to=2014-01-01
# Processing variable VWC_1_2_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49276/measures?from=2013-12-01&to=2014-01-01
# Processing variable VWC_1_3_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49277/measures?from=2013-12-01&to=2014-01-01
# Processing variable VWC_1_4_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49278/measures?from=2013-12-01&to=2014-01-01
# Processing year 2014 month 1
# Processing variable SW_IN_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48656/measures?from=2014-01-01&to=2014-02-01
# Processing variable TA_1_1_2 at https://maq-observations.nl/wp-json/maq/v1/streams/48654/measures?from=2014-01-01&to=2014-02-01
# Processing variable RH_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48655/measures?from=2014-01-01&to=2014-02-01
# Processing variable WS_2_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/48669/measures?from=2014-01-01&to=2014-02-01
# Processing variable P_1_1_7 at https://maq-observations.nl/wp-json/maq/v1/streams/48666/measures?from=2014-01-01&to=2014-02-01
# Processing variable VWC_1_1_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49275/measures?from=2014-01-01&to=2014-02-01
# Processing variable VWC_1_2_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49276/measures?from=2014-01-01&to=2014-02-01
# Processing variable VWC_1_3_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49277/measures?from=2014-01-01&to=2014-02-01
# Processing variable VWC_1_4_1 at https://maq-observations.nl/wp-json/maq/v1/streams/49278/measures?from=2014-01-01&to=2014-02-01
# Veenkampen Data:
#                date-time  year  month  day  hour     Rg     Ta      RH      u  \
# 0    2013-01-01 00:00:00  2013      1    1     0 -2.271  8.365  91.302  8.053
# 1    2013-01-01 01:00:00  2013      1    1     1 -2.182  8.269  91.625  7.567
# 2    2013-01-01 02:00:00  2013      1    1     2 -2.094  8.354  92.010  6.691
# 3    2013-01-01 03:00:00  2013      1    1     3 -2.012  8.138  92.665  7.058
# 4    2013-01-01 04:00:00  2013      1    1     4 -1.992  8.179  92.972  6.755
# ...                  ...   ...    ...  ...   ...    ...    ...     ...    ...
# 8756 2013-12-31 20:00:00  2013     12   31    20 -3.500  6.569  66.224  6.469
# 8757 2013-12-31 21:00:00  2013     12   31    21 -3.633  6.101  71.205  5.670
# 8758 2013-12-31 22:00:00  2013     12   31    22 -3.692  6.098  71.852  5.185
# 8759 2013-12-31 23:00:00  2013     12   31    23 -3.865  5.739  81.448  5.635
# 8760 2014-01-01 00:00:00  2014      1    1     0 -3.582  5.824  86.390  6.963
#
#          P  smc_065  smc_125  smc_250  smc_500
# 0     0.00    0.712    0.689    0.691    0.741
# 1     0.00    0.712    0.690    0.691    0.741
# 2     0.00    0.713    0.690    0.691    0.740
# 3     0.00    0.713    0.689    0.691    0.740
# 4     0.00    0.713    0.689    0.691    0.740
# ...    ...      ...      ...      ...      ...
# 8756  0.02    0.684    0.679    0.670    0.737
# 8757  0.00    0.684    0.679    0.670    0.738
# 8758  0.13    0.683    0.679    0.669    0.737
# 8759  0.63    0.684    0.679    0.670    0.737
# 8760  0.07    0.686    0.679    0.670    0.738
#
# [8761 rows x 14 columns]
